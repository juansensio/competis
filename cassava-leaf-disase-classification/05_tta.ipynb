# %%
import pytorch_lightning as pl
import torch 
from pytorch_lightning.metrics.functional.classification import accuracy
from tqdm import tqdm
from src import DataModule, Resnet
import torchvision
import pandas as pd 
from pathlib import Path
from skimage import io

# %%
model = Resnet.load_from_checkpoint(checkpoint_path='./resnet18-256-da-val_acc=0.80391.ckpt')
model.hparams
# Out:
# "backbone":    resnet18
# "batch_size":  256
# "extra_data":  1
# "lr":          0.0003
# "max_epochs":  50
# "optimizer":   Adam
# "precision":   16
# "seed":        42
# "size":        256
# "subset":      0.1
# "test_size":   0.2
# "train_trans": {'RandomCrop': {'height': 256, 'width': 256}, 'HorizontalFlip': {}, 'VerticalFlip': {}}
# "upsample":    0
# "val_batches": 10
# "val_trans":   {'CenterCrop': {'height': 256, 'width': 256}}

# %%
dm = DataModule(
    file = 'train_extra.csv', 
    batch_size=512,
    val_trans={
        'CenterCrop': {
            'height': model.hparams.size, 
            'width': model.hparams.size
        }
    }
)
dm.setup()
# Out:
# Training samples:  21642
# Validation samples:  5411

# %%
 def evaluate(model, dl):   
    model.eval()
    model.cuda()
    acc = []
    with torch.no_grad():
        t = tqdm(dl)
        for x, y in t:
            x, y = x.cuda(), y.cuda()
            y_hat = model(x)
            acc.append(accuracy(y_hat, y).item())
            t.set_description(f"acc {np.mean(acc):.5f}")
            
evaluate(model, dm.val_dataloader())
# Out:
# acc 0.79620: 100%|██████████| 11/11 [00:39<00:00,  3.59s/it]

# %%
dm = DataModule(
    file = 'train_extra.csv', 
    val_trans={
        'CenterCrop': {
            'height': model.hparams.size, 
            'width': model.hparams.size
        }
    }
)
dm.setup()
# Out:
# Training samples:  21642
# Validation samples:  5411

# %%
def plot_imgs():
    r, c = 1, 5
    fig = plt.figure(figsize=(3*c, 3*r))
    ds = dm.val_ds
    ix = 0
    for _r in range(r):
        for _c in range(c):
            ax = plt.subplot(r, c, _r*c + _c + 1)
            img, label = ds[ix]
            plt.axis("off")
            plt.imshow(img.permute(1,2,0))
            plt.title(label.item())
    plt.tight_layout()
    plt.show()
    
plot_imgs()

# %%
 def evaluate_tta(model, ds, tta = 0, limit = 1):   
    model.eval()
    model.cuda()
    acc = []
    with torch.no_grad():
        t = tqdm(range(len(ds)))
        for ix in t:
            y = ds[ix][1].unsqueeze(0).cuda()
            imgs = torch.stack([ds[ix][0] for i in range(tta+1)]).cuda()
            y_hat = model(imgs).mean(axis=0).unsqueeze(0)
            acc.append(accuracy(y_hat, y).item())
            t.set_description(f"acc {np.mean(acc):.5f}")
            if ix >= int(limit*len(ds)):
                break
            
evaluate_tta(model, dm.val_ds, limit=0.1)
# Out:
# acc 0.80443:  10%|▉         | 541/5411 [00:11<01:39, 48.84it/s]

# %%
evaluate_tta(model, dm.val_ds, tta = 10, limit=0.1)
# Out:
# acc 0.80443:  10%|▉         | 541/5411 [00:47<07:08, 11.37it/s]

# %%
dm = DataModule(
    file = 'train_extra.csv', 
    val_trans={
        'RandomCrop': {
            'height': model.hparams.size, 
            'width': model.hparams.size
        }
    }
)
dm.setup()
# Out:
# Training samples:  21642
# Validation samples:  5411

# %%
plot_imgs()

# %%
evaluate_tta(model, dm.val_ds, tta = 10, limit=0.1)
# Out:
# acc 0.81550:  10%|▉         | 541/5411 [00:46<07:02, 11.51it/s]

# %%
evaluate_tta(model, dm.val_ds, tta = 20, limit=0.1)
# Out:
# acc 0.82103:  10%|▉         | 541/5411 [01:26<12:59,  6.25it/s]

# %%
dm = DataModule(
    file = 'train_extra.csv', 
    val_trans={
        'RandomCrop': {
            'height': model.hparams.size, 
            'width': model.hparams.size
        },
        'HorizontalFlip': {},
        'VerticalFlip': {}
    }
)
dm.setup()
# Out:
# Training samples:  21642
# Validation samples:  5411

# %%
evaluate_tta(model, dm.val_ds, tta = 10, limit=0.1)
# Out:
# acc 0.82472:  10%|▉         | 541/5411 [00:47<07:05, 11.44it/s]

# %%
import torchvision

class FinalModel(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
        self.trans = torch.nn.Sequential(
            torchvision.transforms.RandomCrop(256),
            torchvision.transforms.RandomHorizontalFlip(),
            torchvision.transforms.RandomVerticalFlip()
        )
    
    def forward(self, x, tta : int = 1):
        x = x.float() / 255.
        x = x.permute(2, 0, 1)
        imgs = torch.stack([self.trans(x) for i in range(tta)])
        y_hat = self.model(imgs).mean(dim=0)
        return torch.argmax(y_hat)

# %%
final_model = FinalModel(model.resnet.cpu())

# %%
 def evaluate_tta_script(model, ds, tta = 1, limit = 1.):   
    model.eval()
    model.cuda()
    acc = []
    with torch.no_grad():
        t = tqdm(range(len(ds)))
        for ix in t:
            x, y = ds[ix]
            x, y = x.cuda(), y.cuda()
            # simulate test
            x *= 255. 
            x = x.permute(1, 2, 0).long()
            #print(x.shape, x.dtype, x.max(), x.min())
            y_hat= model(x, tta)
            acc.append((y_hat == y).item())
            t.set_description(f"acc {np.mean(acc):.5f}")
            
            if ix >= int(limit*len(ds)):
                break

# %%
#loaded = torch.jit.load('model.pt')

dm = DataModule(
    file = 'train_extra.csv', 
    val_trans= None
)
dm.setup()
# Out:
# Training samples:  21642
# Validation samples:  5411

# %%
evaluate_tta_script(final_model, dm.val_ds, tta = 10, limit = 0.1)
# Out:
# acc 0.81734:  10%|▉         | 541/5411 [00:09<01:23, 57.99it/s]

# %%
script = torch.jit.script(final_model.cpu())

torch.jit.save(script, "model.pt")

# %%
loaded = torch.jit.load('model.pt')

evaluate_tta_script(loaded, dm.val_ds, tta = 10, limit = 0.1)
# Out:
# acc 0.81919:  10%|▉         | 541/5411 [00:09<01:28, 55.02it/s]

# %%
path = Path('./data/test_images')
images = os.listdir(path)
images_paths = [str(path/img) for img in images]
len(images)
# Out:
# 1

# %%
def predict(model, imgs, tta = 1):   
    model.eval()
    preds = []
    with torch.no_grad():
        for img in imgs:
            img = torch.from_numpy(io.imread(img))
            y_hat = model(img, tta)
            preds.append(y_hat.item())
    return preds

# %%
loaded = torch.jit.load('model.pt')
preds = predict(loaded, images_paths, tta = 50)
preds
# Out:
# [2]

# %%
submission = pd.DataFrame({'image_id': images, 'label': preds })
submission
# Out:
#          image_id  label
# 0  2216849948.jpg      2

# %%
submission.to_csv('submission.csv', index=False)
