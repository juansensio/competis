# %%
from glob import glob
from src import Module, DataModule, DatasetFCI, DatasetFCIm
import torch 
import torchmetrics 
from tqdm import tqdm
import os 
from skimage import io
import shutil
import numpy as np
import pandas as pd

# %%
checkpoints = glob('./checkpoints/*')
checkpoints
# Out:
# ['./checkpoints/myunet-rs50-fcim-lrs-val_metric=0.68107-epoch=14.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-val_metric=0.67217-epoch=16.ckpt',
#  './checkpoints/myunet-serx101-fcim-lrs-val_metric=0.66931-epoch=14.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-epoch=29.ckpt',
#  './checkpoints/myunet-serx101-fcim-lrs-da-val_metric=0.65259-epoch=10.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-epoch=99.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-focal-val_metric=0.00334-epoch=0.ckpt',
#  './checkpoints/unetpp-rs50-fcim-da-epoch=29.ckpt',
#  './checkpoints/myunet-serx101-fcim-lrs-da-epoch=12.ckpt',
#  './checkpoints/unetpp-rs50-fcim-da-epoch=29-v1.ckpt',
#  './checkpoints/unetpp-rs50-fcim-da-val_metric=0.67048-epoch=26.ckpt',
#  './checkpoints/myunet-serx101-fcim-lrs-epoch=29.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-focal-epoch=9.ckpt',
#  './checkpoints/unetpp-rs50-fcim-lrs-val_metric=0.68205-epoch=15.ckpt',
#  './checkpoints/myunet-rs50-fcim-lrs-epoch=29.ckpt',
#  './checkpoints/unetpp-rs50-fcim-da-val_metric=0.66485-epoch=29.ckpt']

# %%
models = [
	('UnetPlusPlus', 'timm-resnest50d', 'unetpp-rs50-fcim-lrs-val_metric=0.68205-epoch=15.ckpt'),
	('MyUnet', 'resnest50d', 'myunet-rs50-fcim-lrs-val_metric=0.68107-epoch=14.ckpt')
]

# %%
def eval(models, device=1, mask_loss=True):
	dm = DataModule(Dataset="DatasetFCIm")
	dm.setup()
	all_preds = []
	for model in models:
		architecture, encoder, name = model
		print(name)
		checkpoint = f'./checkpoints/{name}'
		state_dict = torch.load(checkpoint, map_location='cpu')['state_dict']
		module = Module({"encoder": encoder, "in_chans": 5, "pretrained": None, "padding": 1, "mask_loss": True, "architecture": architecture})
		module.load_state_dict(state_dict)
		module.eval()
		module.cuda(device)
		preds, gt = torch.tensor([]), torch.tensor([])
		with torch.no_grad():
			for batch in tqdm(dm.val_dataloader()):
				x, y = batch
				if mask_loss: x = x[...,:-1]
				x = x.cuda(device)
				y_hat = module(x)
				probas = torch.sigmoid(y_hat)
				preds = torch.cat([preds, probas.cpu()])
				gt = torch.cat([gt, y])
		all_preds.append(preds)
	all_preds = torch.stack(all_preds).mean(0)
	metric = torchmetrics.Dice()
	metric(all_preds, gt.long().unsqueeze(1))
	return metric.compute().item()

# %%
eval(models)
# Out:
# unetpp-rs50-fcim-lrs-val_metric=0.68205-epoch=15.ckpt
# 100%|██████████| 36/36 [00:25<00:00,  1.40it/s]
# myunet-rs50-fcim-lrs-val_metric=0.68107-epoch=14.ckpt
# 100%|██████████| 36/36 [00:20<00:00,  1.77it/s]
# 0.6871915459632874

# %%
images = glob('data/test_satellite/*.tif')
len(images)
# Out:
# 1426

# %%
image_ids = sorted([image.split('/')[-1].split('_')[0] for image in images])
len(image_ids)
# Out:
# 1426

# %%
test_ds = DatasetFCIm(image_ids, mode="test", image_folder="test_satellite")

image, image_id = test_ds[0]
image.shape, image.dtype, image.max(), image.min(), image_id
# Out:
# ((350, 350, 6), dtype('float32'), 1.0, 0.0, 'AA408972')

# %%
def generate_masks(models, device=1, mask_loss=True, th=0.5):
	images = glob('data/test_satellite/*.tif')
	image_ids = sorted([image.split('/')[-1].split('_')[0] for image in images])
	test_ds = DatasetFCIm(image_ids, mode="test", image_folder="test_satellite")
	test_dl = torch.utils.data.DataLoader(test_ds, batch_size=10, shuffle=False, num_workers=4)
	# !rm -rf ./data/test_kelp
	os.makedirs('./data/test_kelp', exist_ok=True)
	all_preds = []
	for model in models:
		architecture, encoder, name = model
		print(name)
		checkpoint = f'./checkpoints/{name}'
		state_dict = torch.load(checkpoint, map_location='cpu')['state_dict']
		module = Module({"encoder": encoder, "in_chans": 5, "pretrained": None, "padding": 1, "mask_loss": True, "architecture": architecture})
		module.load_state_dict(state_dict)
		module.eval()
		module.cuda(device)
		preds = torch.tensor([])
		with torch.no_grad():
			for batch in tqdm(test_dl):
				x, _ = batch
				if mask_loss: x = x[...,:-1]
				x = x.cuda(device)
				y_hat = module(x)
				probas = torch.sigmoid(y_hat)
				preds = torch.cat([preds, probas.cpu()])
		all_preds.append(preds)
	all_preds = torch.stack(all_preds).mean(0)
	all_preds = all_preds > th
	all_preds = all_preds.long().squeeze(1)
	all_preds = all_preds.cpu().numpy().astype('uint8')
	for i, image_id in enumerate(image_ids):
		io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])

# %%
generate_masks(models)
# Out:
# unetpp-rs50-fcim-lrs-val_metric=0.68205-epoch=15.ckpt
# 100%|██████████| 143/143 [00:34<00:00,  4.15it/s]
# myunet-rs50-fcim-lrs-val_metric=0.68107-epoch=14.ckpt
# 100%|██████████| 143/143 [00:24<00:00,  5.91it/s]
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AA408972_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AA804258_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AB121622_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AB144957_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AB363647_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AB455766_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AC615524_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AC799254_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AD373903_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AD551860_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AD752255_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AE222314_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AE567383_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AF436759_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AG694469_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AH316092_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AH395915_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AI326222_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AJ443674_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AJ579285_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AJ608307_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AJ762184_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AJ835538_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AK488371_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AK585995_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AK908577_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AL110372_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AL333517_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AL431845_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AL835916_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AL987873_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AM774810_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AO220098_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AO398179_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AP184643_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AP808308_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AQ211642_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AQ762308_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AR220784_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AR380216_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AR491794_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AR682032_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AS147310_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AS282138_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AS556231_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AS629146_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AT196407_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AT359520_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AT599676_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AU563459_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AV855731_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AX665621_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AX880573_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AY523709_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AY652133_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/AZ858214_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BA323193_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BA356430_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BA805703_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BA993385_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BB140804_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BB574909_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BC390828_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BC435027_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BC595002_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BD115626_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BD416722_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BD643269_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BD818025_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BE559859_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BF142875_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BF517827_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BG271081_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BH161496_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BH511346_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BH617530_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BH674606_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BI923073_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BJ269054_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BJ508881_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BJ649855_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BJ724702_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BJ786913_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BK776096_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BK937167_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BK994016_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BL230484_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BL838862_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BM293439_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BM498494_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BO730839_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BP333238_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BP372864_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BP942455_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BQ210531_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BQ265381_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BR581416_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BR848985_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BS603787_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BS834549_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BT104892_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BU573401_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BU757756_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BU778506_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BV419970_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BX244495_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BX335455_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BY885608_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BZ349382_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/BZ845305_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CA167603_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CA531225_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CA858232_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CA884972_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CA916782_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CB733870_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CC414467_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CC972176_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CD194960_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CD688130_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CD958620_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CE258932_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CF491526_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CF564937_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CF841561_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CF867324_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CG397917_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CG570284_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CG580115_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CG601532_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CH479279_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CH728958_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CI524745_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CJ804313_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CK233730_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CK290357_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CK490904_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CL713571_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CL932992_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CL983073_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CM129096_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CN415386_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CO169793_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CO996593_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CP306984_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CP675074_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CP811047_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CQ481456_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CQ739705_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CR592984_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CR918506_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CR996302_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CS259825_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CS490917_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU116470_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU549433_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU755669_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU811755_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU988544_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CU996840_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CV578179_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CW162823_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CW258366_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CW266465_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CX437004_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CX624977_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CX819368_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CX916338_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CY636561_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/CZ222137_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DA674348_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DA817041_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DA871411_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DB103827_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DB290573_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DB677279_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DB838352_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DD272420_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DD882597_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE188642_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE191537_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE301238_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE302950_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE312705_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE520775_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE862091_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DE916615_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DF334807_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DF408433_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DF920102_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DG479205_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DG735553_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DH220783_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DH533032_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DJ382271_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DJ472409_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DK278026_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DL218881_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DL550797_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DL923073_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DM693083_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DM713501_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DM719433_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DN562094_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DN615947_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DN660333_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DQ670421_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DQ852016_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DS325539_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DS403404_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DT950216_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DU274195_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DU699475_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DV657695_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DV679764_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DV681395_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DW940089_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DX240221_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DX255245_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DY141291_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DZ270261_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DZ801396_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/DZ932369_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EA365940_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EA731147_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB266240_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB302472_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB643114_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB660957_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB802812_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EB824851_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EC437488_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EE114549_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EE857878_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EF225777_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EF478059_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EF864234_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EG145980_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EG987454_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EH760957_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EI453700_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EI966785_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EJ392896_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EJ494747_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EJ873644_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EL271241_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EM802629_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EN907455_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EN974536_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EO663095_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EO813999_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EP138817_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EP528841_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EP785592_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EP953403_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EP962392_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EQ617488_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EQ877935_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ER454437_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ES721121_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ES737355_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ET397158_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ET640546_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ET660069_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ET665987_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ET713350_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EU771440_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EV263040_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EV677723_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EW111901_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EW807459_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EX414565_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/EY136855_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# ...
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YU267800_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YU468451_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YU900234_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YV332518_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YV832851_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YW359322_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YW704106_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YW864060_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YX911017_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY159185_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY267230_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY522041_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY679751_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY711593_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY787351_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YY815338_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YZ217149_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/YZ357034_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZA232250_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZA533843_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZA930116_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZB245893_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZB409234_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZB699070_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZB777015_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZB879930_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZC342765_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZC458143_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZC470399_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZD446747_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZD855408_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZD857065_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZE148933_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZE287743_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZE683397_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZE945097_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZF278240_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZF321321_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZF659890_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZF993761_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZG232315_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZG254511_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZG901351_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZG986993_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZH386939_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZH460678_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZI338804_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZI368880_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZI508482_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZI567785_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZI720148_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZJ351083_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZJ403257_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZJ741714_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZK228479_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZK747454_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZM482746_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZM762574_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZM828326_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZN856486_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZO117072_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZO753453_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZO868804_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZP147899_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZP169730_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZP622873_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZP624344_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZP954222_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZQ228594_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZQ432951_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZQ938792_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZR300188_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZR483542_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZR933456_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZS373094_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZS436314_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZS993650_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZT817395_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZU433614_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZU654634_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZV488027_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZV744755_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZV790507_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZV849019_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZW269654_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZW859340_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZX515035_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZY257482_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZY491267_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZY575159_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])
# /tmp/ipykernel_295921/2295014859.py:33: UserWarning: data/test_kelp/ZY737533_kelp.tif is a low contrast image
#   io.imsave(f'data/test_kelp/{image_id}_kelp.tif', all_preds[i])

# %%
generated_masks = glob('data/test_kelp/*.tif')
len(generated_masks)
# Out:
# 1426

# %%
mask = io.imread(generated_masks[0])
mask.shape, mask.dtype, mask.max(), mask.min()
# Out:
# ((350, 350), dtype('uint8'), 1, 0)

# %%
# !rm -rf submission.zip
shutil.make_archive('submission', 'zip', 'data/test_kelp')
# Out:
# '/home/juan/Desktop/competis/KelpWanted/submission.zip'

# %%
examples = glob('data/submission_format/*.tif')
len(examples)
# Out:
# 1426

# %%
mask = io.imread(examples[0])
mask.shape, mask.dtype, mask.max(), mask.min()
# Out:
# ((350, 350), dtype('uint8'), 1, 0)
