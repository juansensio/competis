# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dm import DFTemporalDataModule
from src.module import UnetTemporalDF

# %%
import torch 

checkpoint = 'checkpoints/unet_df_temp_indexes-val_metric=7900.86279-epoch=218.ckpt'

hparams = {
	'encoder': 'resnet18',
    'pretrained': 'imagenet',
    'in_channels_s1': 2,
    'in_channels_s2': 8,
    "seq_len": 12
}

# module = UNet.load_from_checkpoint(checkpoint)
# module.hparams

state_dict = torch.load(checkpoint)['state_dict']
module = UnetTemporalDF(hparams)
module.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
# dm = RGBTemporalDataModule()
dm = DFTemporalDataModule(s2_bands=(2,1,0,7,9), use_ndvi=True, use_ndwi=True, use_clouds=True)
dm.setup()
# Out:
# train: 8689
# test: 2773

# %%
class Identity:
    def __call__(self, x):
        return x

class Rot90:
    def __init__(self, axes=(3, 4)):
        self.axes = axes
    def __call__(self, x):
        return torch.rot90(x, 1, self.axes)

class Rot180:
    def __init__(self, axes=(3, 4)):
        self.axes = axes
    def __call__(self, x):
        return torch.rot90(x, 2, self.axes)

class Rot270:
    def __init__(self, axes=(3, 4)):
        self.axes = axes
    def __call__(self, x):
        return torch.rot90(x, 3, self.axes)

class HFlip:
    def __init__(self, axis=3):
        self.axis = axis
    def __call__(self, x):
        return torch.flip(x, [self.axis])

class VFlip:
    def __init__(self, axis=4):
        self.axis = axis
    def __call__(self, x):
        return torch.flip(x, [self.axis])

class Transpose:
    def __init__(self, axes=(3, 4)):
        self.axes = axes
    def __call__(self, x):
        return torch.transpose(x, self.axes[0], self.axes[1])

trans = [
    (Identity(), Identity()),
    (Rot90(), Rot270()),
    (Rot180(), Rot180()),
    (Rot270(), Rot90()),
    (HFlip(), HFlip()),
    (VFlip(), VFlip()),
    (Transpose(), Transpose()),
]

# %%
import torch 
import matplotlib.pyplot as plt 

dl = dm.train_dataloader(batch_size=1)
s1, s2, labels = next(iter(dl))

def get_image(x):
	return x[0][-1][:3,...].permute(1, 2, 0)

fig, ax = plt.subplots(len(trans), 3, figsize=(10, 3*len(trans)))
for i, (t1, t2) in enumerate(trans):
	ax[i, 0].imshow(get_image(s2))
	ax[i, 0].axis('off')
	ax[i, 1].imshow(get_image(t1(s2)))
	ax[i, 1].axis('off')
	ax[i, 2].imshow(get_image(t2(t1(s2))))
	ax[i, 2].axis('off')
plt.tight_layout()
plt.show()

# %%
trans = [
    (Identity(), Identity()),
    (Rot90(), Rot270(axes=(1, 2))),
    (Rot180(), Rot180(axes=(1, 2))),
    (Rot270(), Rot90(axes=(1, 2))),
    (HFlip(), HFlip(axis=0)),
    (VFlip(), VFlip(axis=1)),
    (Transpose(), Transpose(axes=(1, 2))),
]

dl = dm.train_dataloader(batch_size=4, shuffle=False)
s1, s2, labels = next(iter(dl))

module.cuda(1)
preds = []
for t1, t2 in trans:
    preds.append(t2(module.predict(t1(s1.cuda(1)), t1(s2.cuda(1)))))
preds = torch.stack(preds).mean(0).cpu()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))
for i in range(4):
    ax[i, 0].imshow(s1[i][-1][0])
    ax[i, 0].axis('off')
    ax[i, 1].imshow(s2[i][-1][:3,...].permute(1, 2, 0))
    ax[i, 1].axis('off')
    ax[i, 2].imshow(labels[i])
    ax[i, 2].axis('off')
    ax[i, 3].imshow(preds[i])
    ax[i, 3].axis('off')
    ax[i, 3].set_title(torch.sqrt(
            torch.sum((preds[i] - labels[i])**2)).item())
plt.tight_layout()
plt.show()

# %%
trans = [
    (Identity(), Identity()),
    (Rot90(), Rot270(axes=(1, 2))),
    (Rot180(), Rot180(axes=(1, 2))),
    (Rot270(), Rot90(axes=(1, 2))),
    (HFlip(), HFlip(axis=0)),
    (VFlip(), VFlip(axis=1)),
    (Transpose(), Transpose(axes=(1, 2))),
]

dl = dm.test_dataloader(batch_size=4)
s1, s2, _ = next(iter(dl))

module.cuda(1)
preds = []
for t1, t2 in trans:
    preds.append(t2(module.predict(t1(s1.cuda(1)), t1(s2.cuda(1)))))
preds = torch.stack(preds).mean(0).cpu()

fig, ax = plt.subplots(4, 3, figsize=(10, 16))
for i in range(4):
	ax[i, 0].imshow(s1[i][-1][0])
	ax[i, 0].axis('off')
	ax[i, 1].imshow(s2[i][-1][:3,...].permute(1, 2, 0))
	ax[i, 1].axis('off')
	ax[i, 2].imshow(preds[i])
	ax[i, 2].axis('off')
plt.tight_layout()
plt.show()

# %%
from tqdm import tqdm 
from skimage.io import imsave

dl = dm.test_dataloader(batch_size=16)
module.cuda(1)

trans = [
    (Identity(), Identity()),
    (Rot90(), Rot270(axes=(1, 2))),
    (Rot180(), Rot180(axes=(1, 2))),
    (Rot270(), Rot90(axes=(1, 2))),
    # (HFlip(), HFlip(axis=0)),
    # (VFlip(), VFlip(axis=1)),
    # (Transpose(), Transpose(axes=(1, 2))),
]

for s1, s2, chip_ids in tqdm(dl):
	# preds = module.predict(s1.cuda(1), s2.cuda(1))
	preds = []
	for t1, t2 in trans:
		preds.append(t2(module.predict(t1(s1.cuda(1)), t1(s2.cuda(1)))))
	preds = torch.stack(preds).mean(0)
	# preds = preds*(dm.ds_test.max - dm.ds_test.min) + dm.ds_test.min
	# preds = preds*dm.ds_test.std + dm.ds_test.mean
	preds = preds*dm.ds_test.max
	for chip_id, pred in zip(chip_ids, preds.cpu().numpy()):
		imsave(f'./submission/{chip_id}_agbm.tif', pred)
# Out:
#  14%|█▍        | 24/174 [01:04<06:44,  2.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb Cell 9 in <cell line: 17>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> module.cuda(1)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> trans = [
#       <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     (Identity(), Identity()),
#       <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     (Rot90(), Rot270(axes=(1, 2))),
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     # (Transpose(), Transpose(axes=(1, 2))),
#      <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> ]
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> for s1, s2, chip_ids in tqdm(dl):
#      <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> 	# preds = module.predict(s1.cuda(1), s2.cuda(1))
#      <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> 	preds = []
#      <a href='vscode-notebook-cell://ssh-remote%2Bpykon/home/juan/Desktop/competis/TheBioMassters/08_submission_tta.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> 	for t1, t2 in trans:
#
# File ~/miniconda3/lib/python3.8/site-packages/tqdm/std.py:1180, in tqdm.__iter__(self)
#    1177 time = self._time
#    1179 try:
# -> 1180     for obj in iterable:
#    1181         yield obj
#    1182         # Update and possibly print the progressbar.
#    1183         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/Desktop/competis/TheBioMassters/src/ds.py:228, in DFTemporalDataset.__getitem__(self, ix)
#     226     ndvi = (nir - red) / (nir + red + 1e-8)
#     227     ndvi = (ndvi + 1.) / 2.
# --> 228     s2 = np.concatenate([s2, ndvi[..., None]], axis=-1)
#     229 if self.use_ndwi:
#     230     swir_band = self.s2_bands.index(9)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import glob 

files = glob.glob('./submission/*.tif')
assert len(files) == 2773

# %%
# zip folder 

import shutil
shutil.make_archive('submission', 'zip', './submission')
# Out:
# '/home/juan/Desktop/competis/TheBioMassters/submission.zip'

# %%
import rasterio as rio
import numpy as np

ix = np.random.randint(0, len(files))
ds = rio.open(files[ix])

ds.indexes, ds.shape, ds.count
# Out:
# /home/juan/miniconda3/lib/python3.8/site-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ((1,), (256, 256), 1)

# %%
x = ds.read(1)

x.shape, x.dtype, x.min(), x.max()
# Out:
# ((256, 256), dtype('float32'), 0.048176326, 288.13138)

# %%
plt.imshow(x)
plt.show()
