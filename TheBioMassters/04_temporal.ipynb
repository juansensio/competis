# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.dm import RGBTemporalDataModule

trans = {
	'RandomRotate90': {
		'p': 0.5
	},
	'HorizontalFlip': {
		'p': 0.5
	},
	'VerticalFlip': {
		'p': 0.5
	},
}
# dm = RGBTemporalDataModule(val_size=0.2, batch_size=1, train_trans=trans)
# months = ["September", "October"]
dm = RGBTemporalDataModule(batch_size=1)
dm.setup()
# Out:
# train: 8689
# test: 2773

# %%
dl = dm.train_dataloader()
images, labels = next(iter(dl))

images.shape, images.dtype, images.max(), images.min(), labels.shape
# Out:
# (torch.Size([1, 12, 3, 256, 256]),
#  torch.float32,
#  tensor(1.),
#  tensor(0.),
#  torch.Size([1, 256, 256]))

# %%
import matplotlib.pyplot as plt 

fig, ax = plt.subplots(3, 4, figsize=(10,8))
dl = dm.train_dataloader(shuffle=False)
# dl = dm.train_dataloader()
images, labels = next(iter(dl))
for i in range(3):
	for j in range(4):
		ax[i, j].imshow(images[0][i*4+j].permute(1, 2, 0))
		ax[i, j].axis('off')
plt.tight_layout()
plt.show()

# %%
plt.imshow(labels[0])
plt.axis('off')
plt.show()

# %%
from src.module import BaseTemporalModule
import torch 

hparams = {
	'encoder': 'resnet18',
	'pretrained': 'imagenet',
	'in_channels': 3,
	'seq_len': 12,
}

module = BaseTemporalModule(hparams)

# inputs = torch.randn(4, 12, 3, 256, 256)
inputs = torch.randn(4, 1, 3, 256, 256)
outputs = module(inputs)
outputs.shape
# Out:
# torch.Size([4, 256, 256])

# %%
import pytorch_lightning as pl

dm = RGBTemporalDataModule(batch_size=4)

hparams = {
	'encoder': 'resnet18',
	'pretrained': 'imagenet',
	'in_channels': 3,
	'seq_len': 12,
	'optimizer': 'Adam',
	'optimizer_params': {
		'lr': 1e-3
	},
	# 'scheduler': {
	# 	'OneCycleLR': {
	# 		'max_lr': 1e-2,
	# 		'pct_start': 0.1,
	# 		'total_steps': 1000,
	# 		# 'verbose': True
	# 	}
	# }
}

module = BaseTemporalModule(hparams)

trainer = pl.Trainer(
	gpus=1,
	precision=16,
	overfit_batches=1,
	max_epochs=500,
	logger=None,
	enable_checkpointing=False,
)

trainer.fit(module, dm)
# Out:
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(overfit_batches=1)` was configured so 1 batch will be used.
# train: 8689
# test: 2773
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name              | Type             | Params
# -------------------------------------------------------
# 0 | encoder           | ResNetEncoder    | 11.2 M
# 1 | decoder           | UnetDecoder      | 24.8 M
# 2 | segmentation_head | SegmentationHead | 145
# -------------------------------------------------------
# 36.0 M    Trainable params
# 0         Non-trainable params
# 36.0 M    Total params
# 72.045    Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]

# %%
dl = dm.train_dataloader(shuffle=False)
images, labels = next(iter(dl))
preds = module.predict(images)

preds.shape, preds.dtype, preds.min(), preds.max()
# Out:
# (torch.Size([4, 256, 256]), torch.float32, tensor(1.0003e-05), tensor(0.0337))

# %%
import torch 

fig, ax = plt.subplots(4, 3, figsize=(10, 16))
for i in range(4):
	ax[i, 0].imshow(images[i][-1].permute(1, 2, 0))
	ax[i, 0].axis('off')
	ax[i, 1].imshow(labels[i])
	ax[i, 1].axis('off')
	ax[i, 2].imshow(preds[i])
	ax[i, 2].axis('off')
	ax[i, 2].set_title(torch.sqrt(
            torch.sum((preds[i]*12905.3 - labels[i]*12905.3)**2)).item())
plt.tight_layout()
plt.show()

# %%
import pandas as pd 

train = pd.read_csv('data/test.csv')
train
# Out:
#        Unnamed: 0            filename   chip_id satellite      month  \
# 0             522  00a28320_S1_00.tif  00a28320        S1  September
# 1             523  00a28320_S1_01.tif  00a28320        S1    October
# 2             524  00a28320_S1_02.tif  00a28320        S1   November
# 3             525  00a28320_S1_03.tif  00a28320        S1   December
# 4             526  00a28320_S1_04.tif  00a28320        S1    January
# ...           ...                 ...       ...       ...        ...
# 63343      252421  fff812c0_S2_07.tif  fff812c0        S2      April
# 63344      252422  fff812c0_S2_08.tif  fff812c0        S2        May
# 63345      252423  fff812c0_S2_09.tif  fff812c0        S2       June
# 63346      252424  fff812c0_S2_10.tif  fff812c0        S2       July
# 63347      252425  fff812c0_S2_11.tif  fff812c0        S2     August
#
#       corresponding_agbm
# 0      00a28320_agbm.tif
# 1      00a28320_agbm.tif
# 2      00a28320_agbm.tif
# 3      00a28320_agbm.tif
# 4      00a28320_agbm.tif
# ...                  ...
# 63343  fff812c0_agbm.tif
# 63344  fff812c0_agbm.tif
# 63345  fff812c0_agbm.tif
# 63346  fff812c0_agbm.tif
# 63347  fff812c0_agbm.tif
#
# [63348 rows x 6 columns]

# %%
train = train[train.satellite == 'S2']

# %%
grouped = train.groupby('chip_id').agg(list)[['filename', 'month', 'corresponding_agbm']]
grouped
# Out:
#                                                    filename  \
# chip_id
# 0003d2eb  [0003d2eb_S2_00.tif, 0003d2eb_S2_01.tif, 0003d...
# 000aa810  [000aa810_S2_06.tif, 000aa810_S2_07.tif, 000aa...
# 000d7e33  [000d7e33_S2_06.tif, 000d7e33_S2_07.tif, 000d7...
# 00184691  [00184691_S2_06.tif, 00184691_S2_07.tif, 00184...
# 001b0634  [001b0634_S2_00.tif, 001b0634_S2_01.tif, 001b0...
# ...                                                     ...
# ffc563f4  [ffc563f4_S2_00.tif, ffc563f4_S2_01.tif, ffc56...
# ffc730b9  [ffc730b9_S2_00.tif, ffc730b9_S2_01.tif, ffc73...
# ffc7d4f2  [ffc7d4f2_S2_00.tif, ffc7d4f2_S2_01.tif, ffc7d...
# ffd8db7a  [ffd8db7a_S2_00.tif, ffd8db7a_S2_01.tif, ffd8d...
# fff05995  [fff05995_S2_00.tif, fff05995_S2_01.tif, fff05...
#
#                                                       month  \
# chip_id
# 0003d2eb  [September, October, February, March, April, M...
# 000aa810            [March, April, May, June, July, August]
# 000d7e33            [March, April, May, June, July, August]
# 00184691            [March, April, May, June, July, August]
# 001b0634  [September, October, November, January, Februa...
# ...                                                     ...
# ffc563f4  [September, October, November, January, Februa...
# ffc730b9  [September, October, November, January, Februa...
# ffc7d4f2  [September, October, November, January, Februa...
# ffd8db7a  [September, October, November, January, Februa...
# fff05995  [September, October, November, January, Februa...
#
#                                          corresponding_agbm
# chip_id
# 0003d2eb  [0003d2eb_agbm.tif, 0003d2eb_agbm.tif, 0003d2e...
# 000aa810  [000aa810_agbm.tif, 000aa810_agbm.tif, 000aa81...
# 000d7e33  [000d7e33_agbm.tif, 000d7e33_agbm.tif, 000d7e3...
# 00184691  [00184691_agbm.tif, 00184691_agbm.tif, 0018469...
# 001b0634  [001b0634_agbm.tif, 001b0634_agbm.tif, 001b063...
# ...                                                     ...
# ffc563f4  [ffc563f4_agbm.tif, ffc563f4_agbm.tif, ffc563f...
# ffc730b9  [ffc730b9_agbm.tif, ffc730b9_agbm.tif, ffc730b...
# ffc7d4f2  [ffc7d4f2_agbm.tif, ffc7d4f2_agbm.tif, ffc7d4f...
# ffd8db7a  [ffd8db7a_agbm.tif, ffd8db7a_agbm.tif, ffd8db7...
# fff05995  [fff05995_agbm.tif, fff05995_agbm.tif, fff0599...
#
# [8689 rows x 3 columns]

# %%
labels = []
for chip_id, chip in grouped.iterrows():
	assert len(set(chip.corresponding_agbm)) == 1
	labels.append(chip['corresponding_agbm'][0])
grouped['corresponding_agbm'] = labels
grouped
# Out:
#                                                    filename  \
# chip_id
# 0003d2eb  [0003d2eb_S2_00.tif, 0003d2eb_S2_01.tif, 0003d...
# 000aa810  [000aa810_S2_06.tif, 000aa810_S2_07.tif, 000aa...
# 000d7e33  [000d7e33_S2_06.tif, 000d7e33_S2_07.tif, 000d7...
# 00184691  [00184691_S2_06.tif, 00184691_S2_07.tif, 00184...
# 001b0634  [001b0634_S2_00.tif, 001b0634_S2_01.tif, 001b0...
# ...                                                     ...
# ffc563f4  [ffc563f4_S2_00.tif, ffc563f4_S2_01.tif, ffc56...
# ffc730b9  [ffc730b9_S2_00.tif, ffc730b9_S2_01.tif, ffc73...
# ffc7d4f2  [ffc7d4f2_S2_00.tif, ffc7d4f2_S2_01.tif, ffc7d...
# ffd8db7a  [ffd8db7a_S2_00.tif, ffd8db7a_S2_01.tif, ffd8d...
# fff05995  [fff05995_S2_00.tif, fff05995_S2_01.tif, fff05...
#
#                                                       month corresponding_agbm
# chip_id
# 0003d2eb  [September, October, February, March, April, M...  0003d2eb_agbm.tif
# 000aa810            [March, April, May, June, July, August]  000aa810_agbm.tif
# 000d7e33            [March, April, May, June, July, August]  000d7e33_agbm.tif
# 00184691            [March, April, May, June, July, August]  00184691_agbm.tif
# 001b0634  [September, October, November, January, Februa...  001b0634_agbm.tif
# ...                                                     ...                ...
# ffc563f4  [September, October, November, January, Februa...  ffc563f4_agbm.tif
# ffc730b9  [September, October, November, January, Februa...  ffc730b9_agbm.tif
# ffc7d4f2  [September, October, November, January, Februa...  ffc7d4f2_agbm.tif
# ffd8db7a  [September, October, November, January, Februa...  ffd8db7a_agbm.tif
# fff05995  [September, October, November, January, Februa...  fff05995_agbm.tif
#
# [8689 rows x 3 columns]

# %%
max_len, max_len_chip_id = 0, None
for chip_id, group in grouped.iterrows():
	if len(group.month) > max_len:
		max_len = len(group.month)
		max_len_chip_id = chip_id

max_len, max_len_chip_id
# Out:
# (12, '0060c0a5')

# %%
months = grouped.month.loc[max_len_chip_id]
months
# Out:
# ['September',
#  'October',
#  'November',
#  'December',
#  'January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August']

# %%
filenames = []
for chip_id, group in grouped.iterrows():
	filenames.append([None]*len(months))
	for i,m in enumerate(months):
		if m in group.month:
			filenames[-1][i] = group.filename[group.month.index(m)]

grouped2 = pd.DataFrame({'filename': filenames, 'corresponding_agbm': labels[1]}, index=grouped.index)
grouped2
# Out:
#                                                    filename corresponding_agbm
# chip_id
# 0003d2eb  [0003d2eb_S2_00.tif, 0003d2eb_S2_01.tif, None,...  000aa810_agbm.tif
# 000aa810  [None, None, None, None, None, None, 000aa810_...  000aa810_agbm.tif
# 000d7e33  [None, None, None, None, None, None, 000d7e33_...  000aa810_agbm.tif
# 00184691  [None, None, None, None, None, None, 00184691_...  000aa810_agbm.tif
# 001b0634  [001b0634_S2_00.tif, 001b0634_S2_01.tif, 001b0...  000aa810_agbm.tif
# ...                                                     ...                ...
# ffc563f4  [ffc563f4_S2_00.tif, ffc563f4_S2_01.tif, ffc56...  000aa810_agbm.tif
# ffc730b9  [ffc730b9_S2_00.tif, ffc730b9_S2_01.tif, ffc73...  000aa810_agbm.tif
# ffc7d4f2  [ffc7d4f2_S2_00.tif, ffc7d4f2_S2_01.tif, ffc7d...  000aa810_agbm.tif
# ffd8db7a  [ffd8db7a_S2_00.tif, ffd8db7a_S2_01.tif, ffd8d...  000aa810_agbm.tif
# fff05995  [fff05995_S2_00.tif, fff05995_S2_01.tif, fff05...  000aa810_agbm.tif
#
# [8689 rows x 2 columns]

# %%
grouped2.index.values
# Out:
# array(['0003d2eb', '000aa810', '000d7e33', ..., 'ffc7d4f2', 'ffd8db7a',
#        'fff05995'], dtype=object)
