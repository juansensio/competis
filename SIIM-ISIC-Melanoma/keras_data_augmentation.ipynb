# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import pandas as pd
from tensorflow.keras.applications import ResNet50V2

tf.__version__
# Out:
# '2.3.0-dev20200522'

# %%
PATH = 'data'

os.listdir(PATH)
# Out:
# ['jpeg224',
#  'sample_submission.csv',
#  'subset.csv',
#  'subset_clean.csv',
#  'test.csv',
#  'test_clean.csv',
#  'train.csv',
#  'train_clean.csv',
#  'train_clean_split.csv',
#  'train_split.csv',
#  'val_clean_split.csv',
#  'val_split.csv']

# %%
#train = pd.read_csv(f'{PATH}/train.csv')
train = pd.read_csv(f'{PATH}/subset.csv')
val = pd.read_csv(f'{PATH}/val_split.csv')

train.shape, val.shape
# Out:
# ((2220, 8), (10932, 8))

# %%
train.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0533349  IP_5208504  female        45.0               lower extremity
# 1  ISIC_8814612  IP_0414408    male        50.0                         torso
# 2  ISIC_6515241  IP_6245507    male        45.0               lower extremity
# 3  ISIC_5075261  IP_2117218    male        40.0               upper extremity
# 4  ISIC_2624460  IP_1969685    male        50.0                         torso
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2   unknown           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
BATCH_SIZE = 64
AUTO = tf.data.experimental.AUTOTUNE

def decode(filename, label):
    img = tf.io.read_file(filename)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32)
    return img, label

def augment(img, label):
    # augmentation
    #img = tf.image.flip_left_right(img)
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    return img, label

def load_ds(df):
    options = tf.data.Options()
    options.experimental_deterministic = False
    imgs, labels = df["image_name"].values, df["target"].values
    imgs = [f'{PATH}/jpeg224/train/{img}.jpg' for img in imgs]
    ds = tf.data.Dataset.from_tensor_slices((imgs, labels))
    ds = ds.with_options(options)
    ds = ds.map(decode, num_parallel_calls=AUTO)
    ds = ds.cache()
    ds = ds.map(augment, num_parallel_calls=AUTO)
    ds = ds.shuffle(2048)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTO)
    return ds

# %%
train_ds = load_ds(train)
val_ds = load_ds(val)

# %%
import matplotlib.pyplot as plt
import random

r, c = 3, 5
fig = plt.figure(figsize=(2*c, 2*r))
for _r in range(r):
    for _c in range(c):
        plt.subplot(r, c, _r*c + _c + 1)
        for imgs, labels in train_ds.take(1):
            img = imgs[0].numpy() / 255
            plt.imshow(img)
            plt.axis(False)
plt.show()

# %%
IMAGE_SIZE = (224, 224, 3)

encoder = ResNet50V2(
    include_top=False,
    input_shape=IMAGE_SIZE,
    weights='imagenet'
)
encoder.trainable = False

inputs = keras.Input(shape=IMAGE_SIZE)
#x = keras.layers.experimental.preprocessing.RandomFlip()(inputs)
x = keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)
x = encoder(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 224, 224, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.AUC(name="auc")]
)

# %%
filepath = './checkpoints/checkpoint'
cb = tf.keras.callbacks.ModelCheckpoint(
    filepath = filepath,
    monitor="val_auc",
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode="max"
)

# %%
model.fit(
    train_ds, 
    epochs=10, 
    validation_data=val_ds, 
    validation_steps=10,
    callbacks=[cb]
)
# Out:
# Epoch 1/10
# 35/35 [==============================] - ETA: 0s - loss: 0.1548 - auc: 0.5765
# Epoch 00001: val_auc improved from -inf to 0.40020, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 10s 293ms/step - loss: 0.1548 - auc: 0.5765 - val_loss: 0.1742 - val_auc: 0.4002
# Epoch 2/10
# 35/35 [==============================] - ETA: 0s - loss: 0.1032 - auc: 0.5179
# Epoch 00002: val_auc improved from 0.40020 to 0.52837, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 253ms/step - loss: 0.1032 - auc: 0.5179 - val_loss: 0.1372 - val_auc: 0.5284
# Epoch 3/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0880 - auc: 0.6718
# Epoch 00003: val_auc improved from 0.52837 to 0.60897, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 254ms/step - loss: 0.0880 - auc: 0.6718 - val_loss: 0.0837 - val_auc: 0.6090
# Epoch 4/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0828 - auc: 0.7295
# Epoch 00004: val_auc improved from 0.60897 to 0.71754, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 255ms/step - loss: 0.0828 - auc: 0.7295 - val_loss: 0.1164 - val_auc: 0.7175
# Epoch 5/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0765 - auc: 0.7917
# Epoch 00005: val_auc improved from 0.71754 to 0.75064, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 256ms/step - loss: 0.0765 - auc: 0.7917 - val_loss: 0.0930 - val_auc: 0.7506
# Epoch 6/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0725 - auc: 0.8285
# Epoch 00006: val_auc did not improve from 0.75064
# 35/35 [==============================] - 9s 251ms/step - loss: 0.0725 - auc: 0.8285 - val_loss: 0.1394 - val_auc: 0.6890
# Epoch 7/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0707 - auc: 0.8598
# Epoch 00007: val_auc improved from 0.75064 to 0.79856, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 256ms/step - loss: 0.0707 - auc: 0.8598 - val_loss: 0.0626 - val_auc: 0.7986
# Epoch 8/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0688 - auc: 0.8728
# Epoch 00008: val_auc improved from 0.79856 to 0.80375, saving model to ./checkpoints\checkpoint
# 35/35 [==============================] - 9s 260ms/step - loss: 0.0688 - auc: 0.8728 - val_loss: 0.1059 - val_auc: 0.8037
# Epoch 9/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0672 - auc: 0.8643
# Epoch 00009: val_auc did not improve from 0.80375
# 35/35 [==============================] - 9s 247ms/step - loss: 0.0672 - auc: 0.8643 - val_loss: 0.0708 - val_auc: 0.7998
# Epoch 10/10
# 35/35 [==============================] - ETA: 0s - loss: 0.0636 - auc: 0.8923
# Epoch 00010: val_auc did not improve from 0.80375
# 35/35 [==============================] - 9s 244ms/step - loss: 0.0636 - auc: 0.8923 - val_loss: 0.0992 - val_auc: 0.7710

# %%
model.load_weights(filepath)
model.save("model.h5")

# %%
model.evaluate(val_ds)
# Out:
# 171/171 [==============================] - 31s 184ms/step - loss: 0.0784 - auc: 0.7866
# [0.07842326164245605, 0.7865684628486633]

# %%
test = pd.read_csv(f'{PATH}/test.csv')

test.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %%
def decode_test(filename):
    img = tf.io.read_file(filename)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32)
    return img

def load_test_ds(df):
    imgs = df["image_name"].values
    imgs = [f'{PATH}/jpeg224/test/{img}.jpg' for img in imgs]
    ds = tf.data.Dataset.from_tensor_slices(imgs)
    ds = ds.map(decode_test)
    ds = ds.batch(BATCH_SIZE)
    return ds

# %%
test_ds = load_test_ds(test)

# %%
preds = model.predict(test_ds)

# %%
preds
# Out:
# array([[0.00371864],
#        [0.00264851],
#        [0.01359786],
#        ...,
#        [0.05855301],
#        [0.00403608],
#        [0.17726648]], dtype=float32)

# %%
submission = pd.DataFrame({'image_name': test['image_name'].values, 'target': preds.ravel()})

submission
# Out:
#          image_name    target
# 0      ISIC_0052060  0.003719
# 1      ISIC_0052349  0.002649
# 2      ISIC_0058510  0.013598
# 3      ISIC_0073313  0.001438
# 4      ISIC_0073502  0.001982
# ...             ...       ...
# 10977  ISIC_9992485  0.012104
# 10978  ISIC_9996992  0.131448
# 10979  ISIC_9997917  0.058553
# 10980  ISIC_9998234  0.004036
# 10981  ISIC_9999302  0.177266
#
# [10982 rows x 2 columns]

# %%
submission.to_csv('submission.csv', index=False)
